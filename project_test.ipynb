# %%
import pandas as pd
import requests
import json

# %%
response = requests.get("https://data.cdc.gov/resource/7b9s-s8ck.json?locationabbr=NC&year=2019&stratification2=Overall&stratification3=Overall").json()
response_df = pd.DataFrame(response)
response_df.loc[(response_df["locationdesc"] == "Cumberland")]
# Out:
#      year locationabbr locationdesc geographiclevel datasource  \
# 250  2019           NC   Cumberland          County       NVSS
# 251  2019           NC   Cumberland          County       NVSS
# 252  2019           NC   Cumberland          County       NVSS
# 253  2019           NC   Cumberland          County       NVSS
# 254  2019           NC   Cumberland          County       NVSS
# 255  2019           NC   Cumberland          County       NVSS
# 256  2019           NC   Cumberland          County       NVSS
# 257  2019           NC   Cumberland          County       NVSS
# 258  2019           NC   Cumberland          County       NVSS
# 259  2019           NC   Cumberland          County       NVSS
#
#                        class                         topic data_value  \
# 250  Cardiovascular Diseases             All heart disease      129.4
# 251  Cardiovascular Diseases                    All stroke       21.8
# 252  Cardiovascular Diseases  Coronary heart disease (CHD)       69.5
# 253  Cardiovascular Diseases  Cardiovascular disease (CVD)      168.5
# 254  Cardiovascular Diseases                 Heart failure       25.7
# 255  Cardiovascular Diseases             All heart disease     1092.1
# 256  Cardiovascular Diseases                    All stroke      243.3
# 257  Cardiovascular Diseases  Coronary heart disease (CHD)        637
# 258  Cardiovascular Diseases  Cardiovascular disease (CVD)     1439.2
# 259  Cardiovascular Diseases                 Heart failure      375.2
#
#     data_value_unit                                   data_value_type  ...  \
# 250     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 251     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 252     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 253     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 254     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 255     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 256     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 257     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 258     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 259     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
#
#     data_value_footnote confidence_limit_low confidence_limit_high  \
# 250                  NA                115.8                 144.9
# 251                  NA                   18                  26.6
# 252                  NA                 60.4                  80.3
# 253                  NA                152.8                   182
# 254                  NA                 21.3                  31.3
# 255                  NA               1034.3                1157.4
# 256                  NA                214.2                 267.5
# 257                  NA                577.8                   696
# 258                  NA               1364.4                1516.5
# 259                  NA                341.8                   412
#
#     stratificationcategory1          stratification1 stratificationcategory2  \
# 250               Age group         Ages 35-64 years                    Race
# 251               Age group         Ages 35-64 years                    Race
# 252               Age group         Ages 35-64 years                    Race
# 253               Age group         Ages 35-64 years                    Race
# 254               Age group         Ages 35-64 years                    Race
# 255               Age group  Ages 65 years and older                    Race
# 256               Age group  Ages 65 years and older                    Race
# 257               Age group  Ages 65 years and older                    Race
# 258               Age group  Ages 65 years and older                    Race
# 259               Age group  Ages 65 years and older                    Race
#
#     stratification2 stratificationcategory3 stratification3 locationid
# 250         Overall                     Sex         Overall      37051
# 251         Overall                     Sex         Overall      37051
# 252         Overall                     Sex         Overall      37051
# 253         Overall                     Sex         Overall      37051
# 254         Overall                     Sex         Overall      37051
# 255         Overall                     Sex         Overall      37051
# 256         Overall                     Sex         Overall      37051
# 257         Overall                     Sex         Overall      37051
# 258         Overall                     Sex         Overall      37051
# 259         Overall                     Sex         Overall      37051
#
# [10 rows x 21 columns]
