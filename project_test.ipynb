# %%
import pandas as pd
import requests
import json

# %%
response = requests.get("https://data.cdc.gov/resource/7b9s-s8ck.json?locationabbr=NC&year=2019&stratification2=Overall&stratification3=Overall").json()
response_df = pd.DataFrame(response)
response_df
# Out:
#      year locationabbr locationdesc geographiclevel datasource  \
# 0    2019           NC     Alamance          County       NVSS
# 1    2019           NC     Alamance          County       NVSS
# 2    2019           NC     Alamance          County       NVSS
# 3    2019           NC     Alamance          County       NVSS
# 4    2019           NC     Alamance          County       NVSS
# ..    ...          ...          ...             ...        ...
# 995  2019           NC       Yancey          County       NVSS
# 996  2019           NC       Yancey          County       NVSS
# 997  2019           NC       Yancey          County       NVSS
# 998  2019           NC       Yancey          County       NVSS
# 999  2019           NC       Yancey          County       NVSS
#
#                        class                         topic data_value  \
# 0    Cardiovascular Diseases             All heart disease      113.1
# 1    Cardiovascular Diseases                    All stroke         16
# 2    Cardiovascular Diseases  Coronary heart disease (CHD)       66.9
# 3    Cardiovascular Diseases  Cardiovascular disease (CVD)      141.4
# 4    Cardiovascular Diseases                 Heart failure       28.1
# ..                       ...                           ...        ...
# 995  Cardiovascular Diseases             All heart disease     1061.5
# 996  Cardiovascular Diseases                    All stroke      217.1
# 997  Cardiovascular Diseases  Coronary heart disease (CHD)      592.4
# 998  Cardiovascular Diseases  Cardiovascular disease (CVD)     1359.5
# 999  Cardiovascular Diseases                 Heart failure      473.5
#
#     data_value_unit                                   data_value_type  ...  \
# 0       per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 1       per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 2       per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 3       per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 4       per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# ..              ...                                               ...  ...
# 995     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 996     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 997     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 998     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
# 999     per 100,000  Age-Standardized, Spatiotemporally Smoothed Rate  ...
#
#     data_value_footnote confidence_limit_low confidence_limit_high  \
# 0                    NA                102.2                 127.2
# 1                    NA                 13.5                  19.1
# 2                    NA                 57.1                  77.4
# 3                    NA                125.6                 154.4
# 4                    NA                 22.9                  34.1
# ..                  ...                  ...                   ...
# 995                  NA                  968                1175.3
# 996                  NA                180.4                 279.9
# 997                  NA                  501                 690.7
# 998                  NA               1235.5                1514.7
# 999                  NA                399.9                 562.4
#
#     stratificationcategory1          stratification1 stratificationcategory2  \
# 0                 Age group         Ages 35-64 years                    Race
# 1                 Age group         Ages 35-64 years                    Race
# 2                 Age group         Ages 35-64 years                    Race
# 3                 Age group         Ages 35-64 years                    Race
# 4                 Age group         Ages 35-64 years                    Race
# ..                      ...                      ...                     ...
# 995               Age group  Ages 65 years and older                    Race
# 996               Age group  Ages 65 years and older                    Race
# 997               Age group  Ages 65 years and older                    Race
# 998               Age group  Ages 65 years and older                    Race
# 999               Age group  Ages 65 years and older                    Race
#
#     stratification2 stratificationcategory3 stratification3 locationid
# 0           Overall                     Sex         Overall      37001
# 1           Overall                     Sex         Overall      37001
# 2           Overall                     Sex         Overall      37001
# 3           Overall                     Sex         Overall      37001
# 4           Overall                     Sex         Overall      37001
# ..              ...                     ...             ...        ...
# 995         Overall                     Sex         Overall      37199
# 996         Overall                     Sex         Overall      37199
# 997         Overall                     Sex         Overall      37199
# 998         Overall                     Sex         Overall      37199
# 999         Overall                     Sex         Overall      37199
#
# [1000 rows x 21 columns]

# %%
# rename and delete columns
# remove year, state, county, data source, class, topic, data value type, data_value_footnote,
# confidence_limit_low, confidence_limit_high, stratificationcategory1




# create scatter plot of data between deaths and insurance coverage

# create bar chart with age groups on x axis, deaths and insurance coverage on y axis

# create bar chart with county on x axis, deaths and insurance coverage on y axis

# create bar chart with population ranges on x axis, deaths and insurance coverage on y axis

# pie chart of percent ins coverage by age group by total deaths

# pie chart of percent ins coverage by age group by population range


# merge data sets

# delete counties not in both data sets

# create new column for population ranges
